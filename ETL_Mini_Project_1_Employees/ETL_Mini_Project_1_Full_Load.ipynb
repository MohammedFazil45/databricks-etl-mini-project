# %% [markdown]
# # ETL Mini Project: Employee Data Pipeline (Version 1)
#
# ## Overview
# This notebook orchestrates a simple ETL pipeline for employee data. The purpose is to demonstrate end-to-end data processing using Databricks and PySpark. It performs the following steps:
#
# 1. **Load**: Read the raw employee dataset and create a raw table.
# 2. **Transform**: Apply basic business logic, including filtering employees based on experience and department.
# 3. **Publish**: Select relevant columns and create a final analytics-ready table.
#
# ## Data Flow

# %%
# %run /Users/fazilsouthgate@gmail.com/databricks-etl-mini-project/ETL_Mini_Project_1_Employees/01_load_employees

# %%
# %run /Users/fazilsouthgate@gmail.com/databricks-etl-mini-project/ETL_Mini_Project_1_Employees/02_transform_employees

# %%
# %run /Users/fazilsouthgate@gmail.com/databricks-etl-mini-project/ETL_Mini_Project_1_Employees/03_analytics
