# %%
from pyspark.sql.functions import current_timestamp

raw_df = spark.table("etl_mini_project.raw_orders")

bronze_df = (
    raw_df
    .withColumn("ingestion_ts", current_timestamp())
)

bronze_df.write.format("delta") \
    .mode("append") \
    .saveAsTable("bronze_db.orders")
